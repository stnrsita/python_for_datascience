# %% [markdown]
# <a href="https://colab.research.google.com/github/stnrsita/python_for_datascience/blob/main/Pandas_Project.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %% [markdown]
# # Load dataset

# %%
#@title Upload file

data = pd.read_csv('/content/toyota.csv')
data
# Out:
#                model  year  price transmission  mileage fuelType  tax   mpg  \
# 0               GT86  2016  16000       Manual    24089   Petrol  265  36.2
# 1               GT86  2017  15995       Manual    18615   Petrol  145  36.2
# 2               GT86  2015  13998       Manual    27469   Petrol  265  36.2
# 3               GT86  2017  18998       Manual    14736   Petrol  150  36.2
# 4               GT86  2017  17498       Manual    36284   Petrol  145  36.2
# ...              ...   ...    ...          ...      ...      ...  ...   ...
# 6733              IQ  2011   5500    Automatic    30000   Petrol   20  58.9
# 6734   Urban Cruiser  2011   4985       Manual    36154   Petrol  125  50.4
# 6735   Urban Cruiser  2012   4995       Manual    46000   Diesel  125  57.6
# 6736   Urban Cruiser  2011   3995       Manual    60700   Petrol  125  50.4
# 6737   Urban Cruiser  2011   4495       Manual    45128   Petrol  125  50.4
#
#       engineSize
# 0            2.0
# 1            2.0
# ...

# %%
#@title Connect G-Drive

from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
data = pd.read_csv('/content/drive/MyDrive/Cakap/dataset/toyota.csv')

data.head(15)
# sales_data.tail(8)
# Out:
#     model  year  price transmission  mileage fuelType  tax   mpg  engineSize
# 0    GT86  2016  16000       Manual    24089   Petrol  265  36.2         2.0
# 1    GT86  2017  15995       Manual    18615   Petrol  145  36.2         2.0
# 2    GT86  2015  13998       Manual    27469   Petrol  265  36.2         2.0
# 3    GT86  2017  18998       Manual    14736   Petrol  150  36.2         2.0
# 4    GT86  2017  17498       Manual    36284   Petrol  145  36.2         2.0
# 5    GT86  2017  15998       Manual    26919   Petrol  260  36.2         2.0
# 6    GT86  2017  18522       Manual    10456   Petrol  145  36.2         2.0
# 7    GT86  2017  18995       Manual    12340   Petrol  145  36.2         2.0
# 8    GT86  2020  27998       Manual      516   Petrol  150  33.2         2.0
# 9    GT86  2016  13990       Manual    37999   Petrol  265  36.2         2.0
# 10   GT86  2013  10495       Manual    72000   Petrol  265  36.2         2.0
# ...

# %% [markdown]
# # Lihat Analytical Dataframe

# %%
# Fungsi agregat
data.describe()
# Out:
#               year         price        mileage          tax          mpg  \
# count  6738.000000   6738.000000    6738.000000  6738.000000  6738.000000
# mean   2016.748145  12522.391066   22857.413921    94.697240    63.042223
# std       2.204062   6345.017587   19125.464147    73.880776    15.836710
# min    1998.000000    850.000000       2.000000     0.000000     2.800000
# 25%    2016.000000   8290.000000    9446.000000     0.000000    55.400000
# 50%    2017.000000  10795.000000   18513.000000   135.000000    62.800000
# 75%    2018.000000  14995.000000   31063.750000   145.000000    69.000000
# max    2020.000000  59995.000000  174419.000000   565.000000   235.000000
#
#         engineSize
# count  6738.000000
# mean      1.471297
# std       0.436159
# min       0.000000
# 25%       1.000000
# 50%       1.500000
# 75%       1.800000
# max       4.500000

# %%
new_data = data[['year', 'price', 'mileage', 'tax', 'mpg', 'engineSize']]

# %%
print('Shape: ')
print(data.shape)
print('--------------------------------------')

print('\nInfo: ')
print(data.info())
print('--------------------------------------')

# bagus kalo nilai korelasi mendekati 1
# menentukan variabel dependent dan independent
print('\nCorrelation: ')
print(new_data.corr())
# Out:
# Shape:
# (6738, 9)
# --------------------------------------
#
# Info:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6738 entries, 0 to 6737
# Data columns (total 9 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   model         6738 non-null   object
#  1   year          6738 non-null   int64
#  2   price         6738 non-null   int64
#  3   transmission  6738 non-null   object
#  4   mileage       6738 non-null   int64
#  5   fuelType      6738 non-null   object
#  6   tax           6738 non-null   int64
#  7   mpg           6738 non-null   float64
#  8   engineSize    6738 non-null   float64
# dtypes: float64(2), int64(4), object(3)
# memory usage: 473.9+ KB
# None
# --------------------------------------
#
# Correlation:
#                 year     price   mileage       tax       mpg  engineSize
# year        1.000000  0.420959 -0.727749  0.283455 -0.020607   -0.045567
# ...

# %% [markdown]
# # Check Duplicate & Handle Duplicate

# %%
#@title Identification duplicate

data.duplicated()
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 6733    False
# 6734    False
# 6735    False
# 6736    False
# 6737    False
# Length: 6738, dtype: bool

# %%
check_duplicates = data.duplicated().sum()

print("Jumlah duplikat: ", check_duplicates)
# Out:
# Jumlah duplikat:  39

# %%
data2 = data.copy()
data2
# Out:
#                model  year  price transmission  mileage fuelType  tax   mpg  \
# 0               GT86  2016  16000       Manual    24089   Petrol  265  36.2
# 1               GT86  2017  15995       Manual    18615   Petrol  145  36.2
# 2               GT86  2015  13998       Manual    27469   Petrol  265  36.2
# 3               GT86  2017  18998       Manual    14736   Petrol  150  36.2
# 4               GT86  2017  17498       Manual    36284   Petrol  145  36.2
# ...              ...   ...    ...          ...      ...      ...  ...   ...
# 6733              IQ  2011   5500    Automatic    30000   Petrol   20  58.9
# 6734   Urban Cruiser  2011   4985       Manual    36154   Petrol  125  50.4
# 6735   Urban Cruiser  2012   4995       Manual    46000   Diesel  125  57.6
# 6736   Urban Cruiser  2011   3995       Manual    60700   Petrol  125  50.4
# 6737   Urban Cruiser  2011   4495       Manual    45128   Petrol  125  50.4
#
#       engineSize
# 0            2.0
# 1            2.0
# ...

# %%
#@title Add new column duplicated

data2['duplicated'] = data2.duplicated()
data2
# Out:
#                model  year  price transmission  mileage fuelType  tax   mpg  \
# 0               GT86  2016  16000       Manual    24089   Petrol  265  36.2
# 1               GT86  2017  15995       Manual    18615   Petrol  145  36.2
# 2               GT86  2015  13998       Manual    27469   Petrol  265  36.2
# 3               GT86  2017  18998       Manual    14736   Petrol  150  36.2
# 4               GT86  2017  17498       Manual    36284   Petrol  145  36.2
# ...              ...   ...    ...          ...      ...      ...  ...   ...
# 6733              IQ  2011   5500    Automatic    30000   Petrol   20  58.9
# 6734   Urban Cruiser  2011   4985       Manual    36154   Petrol  125  50.4
# 6735   Urban Cruiser  2012   4995       Manual    46000   Diesel  125  57.6
# 6736   Urban Cruiser  2011   3995       Manual    60700   Petrol  125  50.4
# 6737   Urban Cruiser  2011   4495       Manual    45128   Petrol  125  50.4
#
#       engineSize  duplicated
# ...

# %%
#@title Drop duplicate

data_baru = data.drop_duplicates()
data_baru
# Out:
#                model  year  price transmission  mileage fuelType  tax   mpg  \
# 0               GT86  2016  16000       Manual    24089   Petrol  265  36.2
# 1               GT86  2017  15995       Manual    18615   Petrol  145  36.2
# 2               GT86  2015  13998       Manual    27469   Petrol  265  36.2
# 3               GT86  2017  18998       Manual    14736   Petrol  150  36.2
# 4               GT86  2017  17498       Manual    36284   Petrol  145  36.2
# ...              ...   ...    ...          ...      ...      ...  ...   ...
# 6733              IQ  2011   5500    Automatic    30000   Petrol   20  58.9
# 6734   Urban Cruiser  2011   4985       Manual    36154   Petrol  125  50.4
# 6735   Urban Cruiser  2012   4995       Manual    46000   Diesel  125  57.6
# 6736   Urban Cruiser  2011   3995       Manual    60700   Petrol  125  50.4
# 6737   Urban Cruiser  2011   4495       Manual    45128   Petrol  125  50.4
#
#       engineSize
# 0            2.0
# 1            2.0
# ...

# %% [markdown]
# # Lakukan Filter Dataframe

# %%
#@title Filter with logic operator

data_with_tax_more_than_250 = data[data.tax >= 250]
data_with_tax_more_than_250
# Out:
#               model  year  price transmission  mileage fuelType  tax   mpg  \
# 0              GT86  2016  16000       Manual    24089   Petrol  265  36.2
# 2              GT86  2015  13998       Manual    27469   Petrol  265  36.2
# 5              GT86  2017  15998       Manual    26919   Petrol  260  36.2
# 9              GT86  2016  13990       Manual    37999   Petrol  265  36.2
# 10             GT86  2013  10495       Manual    72000   Petrol  265  36.2
# ...             ...   ...    ...          ...      ...      ...  ...   ...
# 6692   Land Cruiser  2014  25490    Automatic    54000   Diesel  325  34.9
# 6693   Land Cruiser  2004   6450    Automatic   143000   Diesel  325  27.2
# 6694   Land Cruiser  1998  19990       Manual   100000   Diesel  265  23.9
# 6696   Land Cruiser  2006   7240    Automatic   113000   Diesel  555  31.4
# 6698   Land Cruiser  2014  44990    Automatic    60000   Diesel  540  29.7
#
#       engineSize
# 0            2.0
# 2            2.0
# ...

# %%
#@title Multiple filter

multiple_filter = data[(data.tax >= 250) & (data.fuelType == 'Petrol') & (data.year > 2010) & (data.transmission == 'Manual')]
multiple_filter
# Out:
#     model  year  price transmission  mileage fuelType  tax   mpg  engineSize
# 0    GT86  2016  16000       Manual    24089   Petrol  265  36.2         2.0
# 2    GT86  2015  13998       Manual    27469   Petrol  265  36.2         2.0
# 5    GT86  2017  15998       Manual    26919   Petrol  260  36.2         2.0
# 9    GT86  2016  13990       Manual    37999   Petrol  265  36.2         2.0
# 10   GT86  2013  10495       Manual    72000   Petrol  265  36.2         2.0
# 16   GT86  2017  17995       Manual    16444   Petrol  265  36.2         2.0
# 17   GT86  2014  12998       Manual    25499   Petrol  260  36.2         2.0
# 29   GT86  2015  13981       Manual    30500   Petrol  265  36.2         2.0
# 30   GT86  2015  13991       Manual    38126   Petrol  260  36.2         2.0
# 34   GT86  2013  11575       Manual    50584   Petrol  265  36.2         2.0
# 36   GT86  2014  14999       Manual    18389   Petrol  260  36.2         2.0
# ...

# %%
#@title Filter with isin

kolom_engineSize= [2.0, 3.0, 4.0]

filter_with_isin = data[data.engineSize.isin(kolom_engineSize)]
filter_with_isin
# Out:
#        model  year  price transmission  mileage fuelType  tax   mpg  \
# 0       GT86  2016  16000       Manual    24089   Petrol  265  36.2
# 1       GT86  2017  15995       Manual    18615   Petrol  145  36.2
# 2       GT86  2015  13998       Manual    27469   Petrol  265  36.2
# 3       GT86  2017  18998       Manual    14736   Petrol  150  36.2
# 4       GT86  2017  17498       Manual    36284   Petrol  145  36.2
# ...      ...   ...    ...          ...      ...      ...  ...   ...
# 6707   Supra  2019  51995    Semi-Auto     4153   Petrol  145  34.5
# 6708   Supra  2019  49499    Automatic       10   Petrol  145  34.5
# 6709   Supra  2019  48950    Automatic     2771   Petrol  145  34.5
# 6710   Supra  2019  49490    Automatic      162   Petrol  145  34.5
# 6711   Supra  2019  59995    Automatic     9909    Other  150  34.5
#
#       engineSize
# 0            2.0
# 1            2.0
# 2            2.0
# 3            2.0
# 4            2.0
# ...          ...
# 6707         3.0
# ...

# %%
#@title Filter with str accessor

data[data.transmission.str.startswith('Se')]
# Out:
#        model  year  price transmission  mileage fuelType  tax   mpg  \
# 20      GT86  2020  26995    Semi-Auto     1500   Petrol  145  32.8
# 21      GT86  2019  23998    Semi-Auto      913   Petrol  145  32.8
# 26      GT86  2016  15995    Semi-Auto    19460   Petrol  200  39.8
# 37      GT86  2019  27000    Semi-Auto      100   Petrol  145  32.8
# 39      GT86  2019  22200    Semi-Auto    16241   Petrol  145  32.8
# ...      ...   ...    ...          ...      ...      ...  ...   ...
# 6703   Supra  2019  51995    Semi-Auto      250   Petrol  145  34.5
# 6704   Supra  2019  51995    Semi-Auto     1902   Petrol  145  34.5
# 6705   Supra  2019  49990    Semi-Auto     3000   Petrol  145  34.5
# 6706   Supra  2019  49991    Semi-Auto     1000   Petrol  145  34.5
# 6707   Supra  2019  51995    Semi-Auto     4153   Petrol  145  34.5
#
#       engineSize
# 20           2.0
# 21           2.0
# 26           2.0
# 37           2.0
# 39           2.0
# ...          ...
# 6703         3.0
# ...

# %%
data[data.model.str.endswith('ra')]
# Out:
#        model  year  price transmission  mileage fuelType  tax   mpg  \
# 6700   Supra  2019  47498    Semi-Auto      327   Petrol  145  34.5
# 6701   Supra  2019  49994    Semi-Auto      500   Petrol  145  34.5
# 6702   Supra  2019  47500    Semi-Auto        5   Petrol  145  34.5
# 6703   Supra  2019  51995    Semi-Auto      250   Petrol  145  34.5
# 6704   Supra  2019  51995    Semi-Auto     1902   Petrol  145  34.5
# 6705   Supra  2019  49990    Semi-Auto     3000   Petrol  145  34.5
# 6706   Supra  2019  49991    Semi-Auto     1000   Petrol  145  34.5
# 6707   Supra  2019  51995    Semi-Auto     4153   Petrol  145  34.5
# 6708   Supra  2019  49499    Automatic       10   Petrol  145  34.5
# 6709   Supra  2019  48950    Automatic     2771   Petrol  145  34.5
# 6710   Supra  2019  49490    Automatic      162   Petrol  145  34.5
# 6711   Supra  2019  59995    Automatic     9909    Other  150  34.5
#
#       engineSize
# 6700         3.0
# 6701         3.0
# 6702         3.0
# ...

# %%
#@title Filter with nlargest & nsmallest

#Mengambil 8 data belanja pengguna dengan  total pembelian terbanyak
data.nlargest(8, 'price')
# Out:
#               model  year  price transmission  mileage fuelType  tax   mpg  \
# 6711          Supra  2019  59995    Automatic     9909    Other  150  34.5
# 6670   Land Cruiser  2019  54991    Semi-Auto     1000   Diesel  145  30.1
# 6695   Land Cruiser  2020  54550    Automatic     4000   Diesel  150  30.1
# 6688   Land Cruiser  2020  52990    Automatic     1244   Diesel  145  30.1
# 6672   Land Cruiser  2020  52291    Semi-Auto     3104   Diesel  145  30.1
# 6703          Supra  2019  51995    Semi-Auto      250   Petrol  145  34.5
# 6704          Supra  2019  51995    Semi-Auto     1902   Petrol  145  34.5
# 6707          Supra  2019  51995    Semi-Auto     4153   Petrol  145  34.5
#
#       engineSize
# 6711         3.0
# 6670         2.8
# 6695         2.8
# 6688         2.8
# 6672         2.8
# 6703         3.0
# 6704         3.0
# 6707         3.0

# %%
# Mengambil 8 data belanja pengguna dengan  total pembelian terbanyak
data.nsmallest(8, 'price')
# Out:
#          model  year  price transmission  mileage fuelType  tax   mpg  \
# 6427   Avensis  2003    850       Manual   167054   Diesel  205  48.7
# 289    Corolla  2001    899    Automatic    76000   Petrol  300  35.3
# 2447     Yaris  2002    950       Manual   104000   Petrol  200  40.4
# 2635     Yaris  2003    975       Manual   107000   Petrol  145  50.4
# 6431   Avensis  2007   1200    Automatic   120000   Petrol  300  36.7
# 263    Corolla  2004   1250       Manual   111000   Petrol  260  37.2
# 5496      Aygo  2005   1295       Manual    88836   Petrol   20  61.4
# 74     Corolla  2005   1300       Manual   129000   Petrol  260  36.7
#
#       engineSize
# 6427         2.0
# 289          1.6
# 2447         1.5
# 2635         1.0
# 6431         1.8
# 263          1.8
# 5496         1.0
# 74           1.8

# %%
#@title Filter with Query

data.query('year > 2010 and transmission == "Manual" and fuelType == "Petrol" and  engineSize >= 1.5')
# Out:
#        model  year  price transmission  mileage fuelType  tax   mpg  \
# 0       GT86  2016  16000       Manual    24089   Petrol  265  36.2
# 1       GT86  2017  15995       Manual    18615   Petrol  145  36.2
# 2       GT86  2015  13998       Manual    27469   Petrol  265  36.2
# 3       GT86  2017  18998       Manual    14736   Petrol  150  36.2
# 4       GT86  2017  17498       Manual    36284   Petrol  145  36.2
# ...      ...   ...    ...          ...      ...      ...  ...   ...
# 6530   Verso  2015   9495       Manual    34000   Petrol  200  42.8
# 6532   Verso  2017  12200       Manual    44896   Petrol  200  41.5
# 6542   Verso  2011   5999       Manual    67085   Petrol  200  41.5
# 6543   Verso  2016  10990       Manual    19000   Petrol  205  41.5
# 6547   Verso  2016  11691       Manual    19417   Petrol  200  41.5
#
#       engineSize
# 0            2.0
# 1            2.0
# 2            2.0
# 3            2.0
# 4            2.0
# ...          ...
# 6530         1.6
# ...

# %% [markdown]
# # Lakukan Group Dataframe

# %%
data.groupby('model').agg({'price': 'sum'})
# Out:
#                   price
# model
# Auris           8905633
# Avensis         1136701
# Aygo           15502518
# C-HR            9892088
# Camry            296011
# Corolla         5591710
# GT86            1453346
# Hilux           1849395
# IQ                33978
# Land Cruiser    1860845
# PROACE VERSO     430203
# Prius           4407732
# RAV4            8590181
# Supra            608892
# Urban Cruiser     18470
# Verso           1387284
# Verso-S           17240
# Yaris          22393644

# %%
data.groupby('transmission').agg({'fuelType': 'count'})
# Out:
#               fuelType
# transmission
# Automatic         2657
# Manual            3826
# Other                1
# Semi-Auto          254

# %%
data.groupby(['model', 'transmission']).count()[['fuelType']]
# Out:
#                             fuelType
# model         transmission
# Auris         Automatic          527
#               Manual             183
#               Semi-Auto            2
# Avensis       Automatic           18
#               Manual              95
#               Semi-Auto            2
# Aygo          Automatic          111
#               Manual            1693
#               Semi-Auto          157
# C-HR          Automatic          394
#               Manual              85
# Camry         Automatic           11
# Corolla       Automatic          185
#               Manual              82
# GT86          Automatic            6
#               Manual              61
#               Semi-Auto            6
# Hilux         Automatic           42
#               Manual              44
# IQ            Automatic            3
#               Manual               5
# Land Cruiser  Automatic           21
#               Manual               3
# ...

# %% [markdown]
# # Lakukan replace dataframe

# %%
#@title Replace Values in Column
# replace(oldvalue, newvalue)

data2['transmission'] = data2['transmission'].replace('Manual','Standar')
print(data2)
# Out:
#                model  year  price transmission  mileage fuelType  tax   mpg  \
# 0               GT86  2016  16000      Standar    24089   Petrol  265  36.2
# 1               GT86  2017  15995      Standar    18615   Petrol  145  36.2
# 2               GT86  2015  13998      Standar    27469   Petrol  265  36.2
# 3               GT86  2017  18998      Standar    14736   Petrol  150  36.2
# 4               GT86  2017  17498      Standar    36284   Petrol  145  36.2
# ...              ...   ...    ...          ...      ...      ...  ...   ...
# 6733              IQ  2011   5500    Automatic    30000   Petrol   20  58.9
# 6734   Urban Cruiser  2011   4985      Standar    36154   Petrol  125  50.4
# 6735   Urban Cruiser  2012   4995      Standar    46000   Diesel  125  57.6
# 6736   Urban Cruiser  2011   3995      Standar    60700   Petrol  125  50.4
# 6737   Urban Cruiser  2011   4495      Standar    45128   Petrol  125  50.4
#
#       engineSize  duplicated
# ...

# %%
data2['mpg'] = data2['mpg'].replace(36.2, 36.5)
print(data2)
# Out:
#                model  year  price transmission  mileage fuelType  tax   mpg  \
# 0               GT86  2016  16000      Standar    24089   Petrol  265  36.5
# 1               GT86  2017  15995      Standar    18615   Petrol  145  36.5
# 2               GT86  2015  13998      Standar    27469   Petrol  265  36.5
# 3               GT86  2017  18998      Standar    14736   Petrol  150  36.5
# 4               GT86  2017  17498      Standar    36284   Petrol  145  36.5
# ...              ...   ...    ...          ...      ...      ...  ...   ...
# 6733              IQ  2011   5500    Automatic    30000   Petrol   20  58.9
# 6734   Urban Cruiser  2011   4985      Standar    36154   Petrol  125  50.4
# 6735   Urban Cruiser  2012   4995      Standar    46000   Diesel  125  57.6
# 6736   Urban Cruiser  2011   3995      Standar    60700   Petrol  125  50.4
# 6737   Urban Cruiser  2011   4495      Standar    45128   Petrol  125  50.4
#
#       engineSize  duplicated
# ...

# %%
data2['year'][1] = 2016
print(data2)
# Out:
#                model  year  price transmission  mileage fuelType  tax   mpg  \
# 0               GT86  2016  16000      Standar    24089   Petrol  265  36.5
# 1               GT86  2016  15995      Standar    18615   Petrol  145  36.5
# 2               GT86  2015  13998      Standar    27469   Petrol  265  36.5
# 3               GT86  2017  18998      Standar    14736   Petrol  150  36.5
# 4               GT86  2017  17498      Standar    36284   Petrol  145  36.5
# ...              ...   ...    ...          ...      ...      ...  ...   ...
# 6733              IQ  2011   5500    Automatic    30000   Petrol   20  58.9
# 6734   Urban Cruiser  2011   4985      Standar    36154   Petrol  125  50.4
# 6735   Urban Cruiser  2012   4995      Standar    46000   Diesel  125  57.6
# 6736   Urban Cruiser  2011   3995      Standar    60700   Petrol  125  50.4
# 6737   Urban Cruiser  2011   4495      Standar    45128   Petrol  125  50.4
#
#       engineSize  duplicated
# ...

# %%
#@title Replace multiple values in column

data2['year'] = data2['year'].replace([2011, 2017], 2016)
print(data2)
# Out:
#                model  year  price transmission  mileage fuelType  tax   mpg  \
# 0               GT86  2016  16000      Standar    24089   Petrol  265  36.5
# 1               GT86  2016  15995      Standar    18615   Petrol  145  36.5
# 2               GT86  2015  13998      Standar    27469   Petrol  265  36.5
# 3               GT86  2016  18998      Standar    14736   Petrol  150  36.5
# 4               GT86  2016  17498      Standar    36284   Petrol  145  36.5
# ...              ...   ...    ...          ...      ...      ...  ...   ...
# 6733              IQ  2016   5500    Automatic    30000   Petrol   20  58.9
# 6734   Urban Cruiser  2016   4985      Standar    36154   Petrol  125  50.4
# 6735   Urban Cruiser  2012   4995      Standar    46000   Diesel  125  57.6
# 6736   Urban Cruiser  2016   3995      Standar    60700   Petrol  125  50.4
# 6737   Urban Cruiser  2016   4495      Standar    45128   Petrol  125  50.4
#
#       engineSize  duplicated
# ...

# %%
data2['fuelType'] = data2['fuelType'].replace(['Petrol', 'Diesel'], ['Bensin', 'Solar'])
print(data2)
# Out:
#                model  year  price transmission  mileage fuelType  tax   mpg  \
# 0               GT86  2016  16000      Standar    24089   Bensin  265  36.5
# 1               GT86  2016  15995      Standar    18615   Bensin  145  36.5
# 2               GT86  2015  13998      Standar    27469   Bensin  265  36.5
# 3               GT86  2016  18998      Standar    14736   Bensin  150  36.5
# 4               GT86  2016  17498      Standar    36284   Bensin  145  36.5
# ...              ...   ...    ...          ...      ...      ...  ...   ...
# 6733              IQ  2016   5500    Automatic    30000   Bensin   20  58.9
# 6734   Urban Cruiser  2016   4985      Standar    36154   Bensin  125  50.4
# 6735   Urban Cruiser  2012   4995      Standar    46000    Solar  125  57.6
# 6736   Urban Cruiser  2016   3995      Standar    60700   Bensin  125  50.4
# 6737   Urban Cruiser  2016   4495      Standar    45128   Bensin  125  50.4
#
#       engineSize  duplicated
# ...
